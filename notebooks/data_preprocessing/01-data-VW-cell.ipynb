# %%
import os
import sys
import math
sys.path.append(os.getcwd().partition('notebooks')[0])
from src.config_base import GeneralConfig

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
from src.visualization.visualize_pOCV import VisualizepOCV

# %%
path2files = os.path.join(GeneralConfig.path2data.value,"VW","cell")

# %% [markdown]
# ## VW CC C/45

# %%
data_cc45  = pd.read_pickle(os.path.join(path2files,"VW_LG_78Ah_NMC_20deg_CC_C45.pkl"))

# %%
data_cc45.head()
# Out:
#    Line         U         I             Q  T1[C]       SOC    time_s  \
# 1    29  2.713146  1.811232  8.822011e-07   20.0  0.000001  0.002000
# 2    29  2.715064  1.812534  4.120943e-05   20.0  0.000051  0.082091
# 3    29  2.716789  1.812534  5.033792e-04   20.0  0.000625  0.999999
# 4    29  2.717940  1.812534  1.006876e-03   20.0  0.001251  1.999999
# 5    29  2.718707  1.812534  1.510360e-03   20.0  0.001876  3.000004
#
#        time_ms  time_min        time_h
# 1     2.000000  0.000033  5.555556e-07
# 2    82.091334  0.001368  2.280315e-05
# 3   999.999333  0.016667  2.777776e-04
# 4  1999.999000  0.033333  5.555553e-04
# 5  3000.004334  0.050000  8.333345e-04

# %%
VisualizepOCV().pOCV_voltage_current_charge_plot(data_cc45.time_h,data_cc45.I,data_cc45.U, label = "VW ID.3 CC C/45")
# Out:
# array([[<AxesSubplot: xlabel='charge in Ah', ylabel='voltage in V'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='voltage in V'>],
#        [<AxesSubplot: xlabel='time in hours', ylabel='charge in Ah'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='current in A'>]],
#       dtype=object)

# %% [markdown]
# ## VW CP C/45

# %%
data_cp45  = pd.read_pickle(os.path.join(path2files,"VW_LG_78Ah_NMC_20deg_CP_C45.pkl"))

# %%
data_cp45.head()
# Out:
#    Line         U         I         Q     T1[C]       SOC    time_s  \
# 1    27  2.793678  2.386763  0.000001  20.00000  0.000001  0.002000
# 2    27  2.795595  2.383508  0.000051  20.00000  0.000064  0.077238
# 3    27  2.797321  2.380253  0.000661  20.00000  0.000824  1.000000
# 4    27  2.798279  2.380253  0.001323  20.00000  0.001648  1.999999
# 5    27  2.799046  2.378951  0.001984  20.00351  0.002472  3.000001
#
#        time_ms  time_min        time_h
# 1     1.999666  0.000033  5.554629e-07
# 2    77.237667  0.001287  2.145491e-05
# 3   999.999667  0.016667  2.777777e-04
# 4  1999.999333  0.033333  5.555554e-04
# 5  3000.000667  0.050000  8.333335e-04

# %%
VisualizepOCV().pOCV_voltage_current_charge_plot(data_cp45.time_h,data_cp45.I,data_cp45.U, label = "VW ID.3 CP C/45")
# Out:
# array([[<AxesSubplot: xlabel='charge in Ah', ylabel='voltage in V'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='voltage in V'>],
#        [<AxesSubplot: xlabel='time in hours', ylabel='charge in Ah'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='current in A'>]],
#       dtype=object)

# %% [markdown]
# ## VW CC C/6

# %%
data_cc6  = pd.read_pickle(os.path.join(path2files,"VW_LG_78Ah_NMC_20deg_CC_C6.pkl"))

# %%
data_cc6.head()
# Out:
#    Line         U          I         Q  T1[C]       SOC    time_s     time_ms  \
# 1    53  2.927130  12.984618  0.000007   20.0  0.000009  0.002002    2.001668
# 2    53  2.932499  12.999592  0.000025   20.0  0.000031  0.007001    7.001334
# 3    53  2.934991  12.998941  0.000061   20.0  0.000076  0.016999   16.999002
# 4    53  2.936909  12.999592  0.000170   20.0  0.000211  0.046994   46.994000
# 5    53  2.938826  12.998941  0.000531   20.0  0.000659  0.147012  147.011666
#
#    time_min        time_h
# 1  0.000033  5.560190e-07
# 2  0.000117  1.944815e-06
# 3  0.000283  4.721945e-06
# 4  0.000783  1.305389e-05
# 5  0.002450  4.083657e-05

# %%
VisualizepOCV().pOCV_voltage_current_charge_plot(data_cc6.time_h,data_cc6.I,data_cc6.U, label = "VW ID.3 CC C/6")
# Out:
# array([[<AxesSubplot: xlabel='charge in Ah', ylabel='voltage in V'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='voltage in V'>],
#        [<AxesSubplot: xlabel='time in hours', ylabel='charge in Ah'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='current in A'>]],
#       dtype=object)

# %% [markdown]
# ## VW CP C/6

# %%
data_cp6  = pd.read_pickle(os.path.join(path2files,"VW_LG_78Ah_NMC_20deg_CP_C6.pkl"))

# %%
data_cp6.head()
# Out:
#    Line         U          I         Q    T1[C]       SOC    time_s  \
# 1    45  3.011496  16.037409  0.000009  20.0000  0.000011  0.002000
# 2    45  3.017057  16.060196  0.000031  20.0000  0.000039  0.006999
# 3    45  3.019358  16.058894  0.000076  20.0000  0.000094  0.017005
# 4    45  3.021275  15.963840  0.000275  20.0000  0.000343  0.062006
# 5    45  3.023193  15.918918  0.000784  20.0035  0.000977  0.177014
#
#       time_ms  time_min        time_h
# 1    1.999667  0.000033  5.554630e-07
# 2    6.998666  0.000117  1.944074e-06
# 3   17.004665  0.000283  4.723518e-06
# 4   62.005666  0.001033  1.722380e-05
# 5  177.013667  0.002950  4.917046e-05

# %%
VisualizepOCV().pOCV_voltage_current_charge_plot(data_cp6.time_h,data_cp6.I,data_cp6.U, label = "VW ID.3 CP C/6")
# Out:
# array([[<AxesSubplot: xlabel='charge in Ah', ylabel='voltage in V'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='voltage in V'>],
#        [<AxesSubplot: xlabel='time in hours', ylabel='charge in Ah'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='current in A'>]],
#       dtype=object)
