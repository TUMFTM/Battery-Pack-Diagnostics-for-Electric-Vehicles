# %%
import os
import sys
import math
sys.path.append(os.path.join(os.getcwd().partition('Code')[0], "Code"))
from src.config_base import GeneralConfig

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
from src.visualization.visualize_pOCV import VisualizepOCV

# %%
path2files = os.path.join(GeneralConfig.path2data.value,"VW","halfcell")

# %% [markdown]
# ## VW Anode

# %%
data_a  = pd.read_pickle(os.path.join(path2files,"VW_LG_78Ah_NMC_20deg_C50_Anode.pkl"))

# %%
data_a.head()
# Out:
#    Line         U         I             Q  T1[C]       SOC     time_s  \
# 0    12  1.043415  0.000003  1.984019e-10   20.0  0.000002   0.000000
# 1    12  1.042080  0.000163  2.482372e-10   20.0  0.000003   0.001101
# 2    12  1.021669  0.000163  4.525920e-07   20.0  0.004917  10.000077
# 3    12  1.011178  0.000163  9.049102e-07   20.0  0.009830  20.000031
# 4    12  1.002594  0.000163  1.357239e-06   20.0  0.014744  30.000150
#
#        time_ms  time_min        time_h
# 0      0.00000  0.000000  0.000000e+00
# 1      1.10052  0.000018  3.057000e-07
# 2  10000.07712  0.166668  2.777799e-03
# 3  20000.03112  0.333334  5.555564e-03
# 4  30000.15000  0.500003  8.333375e-03

# %%
VisualizepOCV().pOCV_voltage_current_charge_plot(data_a.time_h,data_a.I,data_a.U, label = "VW ID.3 Anode")
# Out:
# array([[<AxesSubplot: xlabel='charge in Ah', ylabel='voltage in V'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='voltage in V'>],
#        [<AxesSubplot: xlabel='time in hours', ylabel='charge in Ah'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='current in A'>]],
#       dtype=object)

# %% [markdown]
# ## VW Cathode ch

# %%
data_c_ch  = pd.read_pickle(os.path.join(path2files,"VW_LG_78Ah_NMC_20deg_C50_Cathode_ch.pkl"))

# %%
data_c_ch.head()
# Out:
#    Line         U         I             Q  T1[C]           SOC     time_s  \
# 0    13  2.516318  0.000129  3.649446e-11   20.0  4.141839e-07   0.000000
# 1    13  2.673587  0.000134  3.720367e-07   20.0  4.222328e-03   9.998979
# 2    13  2.767759  0.000134  7.441372e-07   20.0  8.445381e-03  19.998980
# 3    13  2.844392  0.000134  1.116238e-06   20.0  1.266843e-02  29.998982
# 4    13  2.910350  0.000134  1.488338e-06   20.0  1.689149e-02  39.998980
#
#        time_ms  time_min    time_h
# 0      0.00000  0.000000  0.000000
# 1   9998.97948  0.166650  0.002777
# 2  19998.98028  0.333316  0.005555
# 3  29998.98180  0.499983  0.008333
# 4  39998.98008  0.666650  0.011111

# %%
VisualizepOCV().pOCV_voltage_current_charge_plot(data_c_ch.time_h,data_c_ch.I,data_c_ch.U, label = "VW ID.3 Cathode ch")
# Out:
# array([[<AxesSubplot: xlabel='charge in Ah', ylabel='voltage in V'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='voltage in V'>],
#        [<AxesSubplot: xlabel='time in hours', ylabel='charge in Ah'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='current in A'>]],
#       dtype=object)

# %% [markdown]
# ## VW Cathode dch

# %%
data_c_dch  = pd.read_pickle(os.path.join(path2files,"VW_LG_78Ah_NMC_20deg_C50_Cathode_dch.pkl"))

# %%
data_c_dch.head()
# Out:
#    Line         U         I             Q  T1[C]       SOC     time_s  \
# 0    12  4.286890  0.000014  9.108480e-10   20.0  0.000010   0.000000
# 1    12  4.285937  0.000133  9.480996e-10   20.0  0.000011   0.001012
# 2    12  4.284984  0.000134  3.732262e-07   20.0  0.004236  10.000214
# 3    12  4.284793  0.000134  7.455401e-07   20.0  0.008461  20.000124
# 4    12  4.284412  0.000134  1.117849e-06   20.0  0.012687  30.000127
#
#        time_ms  time_min        time_h
# 0      0.00000  0.000000  0.000000e+00
# 1      1.01160  0.000017  2.810000e-07
# 2  10000.21392  0.166670  2.777837e-03
# 3  20000.12400  0.333335  5.555590e-03
# 4  30000.12732  0.500002  8.333369e-03

# %%
VisualizepOCV().pOCV_voltage_current_charge_plot(data_c_dch.time_h,data_c_dch.I,data_c_dch.U, label = "VW ID.3 Cathode dch")
# Out:
# array([[<AxesSubplot: xlabel='charge in Ah', ylabel='voltage in V'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='voltage in V'>],
#        [<AxesSubplot: xlabel='time in hours', ylabel='charge in Ah'>,
#         <AxesSubplot: xlabel='time in hours', ylabel='current in A'>]],
#       dtype=object)
