# %%
import os
import sys
import math
sys.path.append(os.path.join(os.getcwd().partition('Code')[0], "Code"))
from src.config_base import GeneralConfig

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
from src.visualization.visualize_pOCV import VisualizepOCV

# %%
path2files = os.path.join(GeneralConfig.path2data.value,"VW","vehicle")

# %% [markdown]
# ## VW 2021

# %%
data_2021  = pd.read_pickle(os.path.join(path2files,"VW_ID3_JB_8A_C40_2021.pkl"))

# %%
data_2021.head()
# Out:
#    time  cell_voltage_67  cell_voltage_69  cell_voltage_70  cell_voltage_66  \
# 4     8         3.313011         3.281034         3.327030         3.308029
# 5    10         3.313106         3.281157         3.327134         3.308133
# 6    12         3.313201         3.281281         3.327239         3.308237
# 7    14         3.313296         3.281404         3.327343         3.308342
# 8    16         3.313391         3.281528         3.327448         3.308446
#
#    cell_voltage_68           U         I       SOC  cell_voltage_71  ...  \
# 4         3.322012  359.303858  4.754081  0.010228         3.325056  ...
# 5         3.322117  359.471076  4.976860  0.012786         3.325140  ...
# 6         3.322222  359.515885  4.735431  0.015343         3.325224  ...
# 7         3.322326  359.535093  5.008918  0.017900         3.325309  ...
# 8         3.322431  359.554301  4.852095  0.020457         3.325393  ...
#
# ...

# %%
VisualizepOCV().pOCV_voltage_current_charge_plot(data_2021.time_h,data_2021.I,data_2021.U, label = "VW ID.3 2021")
# Out:
# array([[<Axes: xlabel='charge in Ah', ylabel='voltage in V'>,
#         <Axes: xlabel='time in hours', ylabel='voltage in V'>],
#        [<Axes: xlabel='time in hours', ylabel='charge in Ah'>,
#         <Axes: xlabel='time in hours', ylabel='current in A'>]],
#       dtype=object)

# %% [markdown]
# ## VW 2023

# %%
data_2023  = pd.read_pickle(os.path.join(path2files,"VW_ID3_JB_8A_C40_2023.pkl"))

# %%
data_2023.head()
# Out:
# name          time  SOC  cell_voltage_51  cell_voltage_65  cell_voltage_35  \
# 36    1.686923e+09  0.0            3.366            3.354            3.365
# 37    1.686923e+09  0.0            3.367            3.355            3.366
# 38    1.686923e+09  0.0            3.368            3.356            3.367
# 39    1.686923e+09  0.0            3.368            3.356            3.367
# 40    1.686923e+09  0.0            3.368            3.357            3.367
#
# name  cell_voltage_72  cell_voltage_104  cell_voltage_1     I       U  ...  \
# 36              3.377             3.357           3.341  4.66  362.50  ...
# 37              3.377             3.359           3.341  4.66  362.50  ...
# 38              3.378             3.359           3.343  4.35  362.50  ...
# 39              3.378             3.359           3.343  4.59  362.75  ...
# 40              3.379             3.360           3.344  4.62  362.75  ...
#
# ...

# %%
VisualizepOCV().pOCV_voltage_current_charge_plot(data_2023.time_h,data_2023.I,data_2023.U, label = "VW ID.3 2023")
# Out:
# array([[<Axes: xlabel='charge in Ah', ylabel='voltage in V'>,
#         <Axes: xlabel='time in hours', ylabel='voltage in V'>],
#        [<Axes: xlabel='time in hours', ylabel='charge in Ah'>,
#         <Axes: xlabel='time in hours', ylabel='current in A'>]],
#       dtype=object)

# %% [markdown]
# ## VW 2024

# %%
data_2023  = pd.read_pickle(os.path.join(path2files,"VW_ID3_JB_8A_C40_2024.pkl"))

# %%
data_2023.head()
# Out:
# name                          date       time_ms     time_s  time_min  \
# 0    2024-04-22 08:37:52.605304241      0.000000   0.000000  0.000000
# 1    2024-04-22 08:37:56.365473032   3760.168791   3.760169  0.062669
# 2    2024-04-22 08:38:00.430376291   7825.072050   7.825072  0.130418
# 3    2024-04-22 08:38:02.675852537  10070.548296  10.070548  0.167842
# 4    2024-04-22 08:38:06.370657682  13765.353441  13.765353  0.229423
#
# name    time_h  SOC       U     I         Q         P  ...  pack_temp_17  \
# 0     0.000000  0.0  361.50  3.68  0.000000  1.330320  ...          23.6
# 1     0.001044  0.0  361.50  3.79  0.003901  1.370085  ...          23.6
# 2     0.002174  0.0  361.50  3.62  0.008085  1.308630  ...          23.6
# 3     0.002797  0.0  361.50  3.76  0.010386  1.359240  ...          23.6
# 4     0.003824  0.0  361.75  3.73  0.014230  1.349328  ...          23.6
#
# name  pack_temp_18  pack_temp_2  pack_temp_3  pack_temp_4  pack_temp_5  \
# ...

# %%
VisualizepOCV().pOCV_voltage_current_charge_plot(data_2023.time_h,data_2023.I,data_2023.U, label = "VW ID.3 2024")
# Out:
# array([[<Axes: xlabel='charge in Ah', ylabel='voltage in V'>,
#         <Axes: xlabel='time in hours', ylabel='voltage in V'>],
#        [<Axes: xlabel='time in hours', ylabel='charge in Ah'>,
#         <Axes: xlabel='time in hours', ylabel='current in A'>]],
#       dtype=object)
